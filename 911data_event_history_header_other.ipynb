# %%
import numpy as np
import pandas as pd
import os

# %%
pd_temp = pd.read_csv('./911call/other/chifoia_ehh_01012018_ad.csv',skiprows=0,header=0)

# %%
pd_temp.head()
# Out:
#    eventnumber            entrydate              ACKDATE   \
# 0    1802809654  01/28/2018 16.34.50  01/28/2018 16.54.22
# 1    1802809655  01/28/2018 16.34.52                  NaN
# 2    1802809656  01/28/2018 16.34.52                  NaN
# 3    1802809657  01/28/2018 16.34.53                  NaN
# 4    1802809658  01/28/2018 16.35.04  01/28/2018 16.35.56
#
#   ADDROFOCCOVERRIDEFLAG  ADVISEDFLAG   ALINUMBER  ARPFLAG    ATOM   ATOMPOL   \
# 0                      N            N    99221009        N   124.0     124.0
# 1                      N            N    99221014        N  1131.0    1131.0
# 2                      N            Y    99221023        N   314.0     314.0
# 3                      N            N           0        N   611.0     611.0
# 4                      N            N    99221018        N  2222.0    2222.0
#
#   CALLERLOCSTREETDIR       ...      REOPENFLAG  RESPGROUP  RESPONSE  SOURCE   \
# ...

# %%
pd_temp.columns
# Out:
# Index(['eventnumber ', 'entrydate ', 'ACKDATE ', 'ADDROFOCCOVERRIDEFLAG ',
#        'ADVISEDFLAG ', 'ALINUMBER ', 'ARPFLAG ', 'ATOM ', 'ATOMPOL ',
#        'CALLERLOCSTREETDIR ', 'CALLERLOCSTREETNAME ', 'CANCELEDFLAG ',
#        'CASE_NUMBER_FLAG ', 'CATCHUPFLAG ', 'CLOSEDATE ', 'CLOSEDATEHN ',
#        'CLRDATE ', 'CONDISPGROUP ', 'CONTACT ', 'DISPATCHED_FLAG ',
#        'DISPDATE ', 'findisposition ', 'DISPWKS ', 'DUPLICATE_FLAG ',
#        'ENRDATE ', 'ENTRYDATEHN ', 'ENTRYWKS ', 'FILE_ADVISED_FLAG ',
#        'FINPRIORITY ', 'FINRESPLEVEL ', 'FINTYPE ', 'INITDISPOSITION ',
#        'INITPRIORITY ', 'INITRESPLEVEL ', 'INITTYPE ', 'LOCCITY ',
#        'LOCDISPGROUP ', 'LOCOVERRIDEFLAG ', 'LOCTYPEFLAG ', 'OOSFLAG ',
#        'OTHERNOTIFIEDFLAG ', 'RECDDATE ', 'RECDDATEHN ', 'REOPENFLAG ',
#        'RESPGROUP ', 'RESPONSE ', 'SOURCE ', 'geo.ward ', 'ali.answerdate ',
#        'ali.asqdate ', 'ali.companyid ', 'ali.direction ', 'ali.equipment'],
#       dtype='object')

# %%
pd_temp['ENRDATE ']
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4        01/28/2018 16.35.57
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9        01/28/2018 16.37.01
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23       01/28/2018 16.38.33
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29       01/28/2018 16.37.35
#                 ...
# 53963                    NaN
# ...

# %% [markdown]
# ['EVENTNUMBER', 'RECDDATE', 'RECDDATEHN', 'ENTRYDATE',
# 'ENTRYDATEHN', 'CLOSEDATE', 'CLOSEDATEHN', 'STATUS', 'ENTRYPERSID',
# 'ENTRYWKS', 'DISPPERSID', 'DISPWKS', 'LOCSTREETDIR', 'LOCSTREETNAME',
# 'SERVICESTREETDIR', 'SERVICESTREETNAME', 'LOCCITY', 'LOCOVERRIDEFLAG',
# 'LOCTYPEFLAG', 'XCOORD', 'YCOORD', 'ATOM', 'RESPGROUP', 'RESPAREA',
# 'CONDISPGROUP', 'LOCDISPGROUP', 'SOURCE', 'INITPRIORITY', 'FINPRIORITY',
# 'CONTACT', 'INITTYPE', 'FINTYPE', 'TYPEDESCR', 'RESPONSE',
# 'INITRESPLEVEL', 'FINRESPLEVEL', 'CALLERLOCSTREETDIR',
# 'CALLERLOCSTREETNAME', 'CATCHUPFLAG', 'OOSFLAG', 'ADVISEDFLAG',
# 'OTHERNOTIFIEDFLAG', 'ARPFLAG', 'REOPENFLAG', 'STACKEDFLAG',
# 'INITDISPOSITION', 'FINDISPOSITION', 'ALINUMBER', 'CLRDATE', 'DISPDATE',
# 'ACKDATE', 'ENRDATE', 'ONSDATE', 'CANCELEDFLAG',
# 'ADDROFOCCOVERRIDEFLAG', 'DISPATCHED_FLAG', 'DUPLICATE_FLAG',
# 'FILE_ADVISED_FLAG', 'CASE_NUMBER_FLAG', 'WIRELESS_FLAG']

# %% [markdown]
# ['eventnumber ', 'entrydate ', 'ACKDATE ', 'ADDROFOCCOVERRIDEFLAG ',
# 'ADVISEDFLAG ', 'ALINUMBER ', 'ARPFLAG ', 'ATOM ', 'ATOMPOL ',
# 'CALLERLOCSTREETDIR ', 'CALLERLOCSTREETNAME ', 'CANCELEDFLAG ',
# 'CASE_NUMBER_FLAG ', 'CATCHUPFLAG ', 'CLOSEDATE ', 'CLOSEDATEHN ',
# 'CLRDATE ', 'CONDISPGROUP ', 'CONTACT ', 'DISPATCHED_FLAG ',
# 'DISPDATE ', 'findisposition ', 'DISPWKS ', 'DUPLICATE_FLAG ',
# 'ENRDATE ', 'ENTRYDATEHN ', 'ENTRYWKS ', 'FILE_ADVISED_FLAG ',
# 'FINPRIORITY ', 'FINRESPLEVEL ', 'FINTYPE ', 'INITDISPOSITION ',
# 'INITPRIORITY ', 'INITRESPLEVEL ', 'INITTYPE ', 'LOCCITY ',
# 'LOCDISPGROUP ', 'LOCOVERRIDEFLAG ', 'LOCTYPEFLAG ', 'OOSFLAG ',
# 'OTHERNOTIFIEDFLAG ', 'RECDDATE ', 'RECDDATEHN ', 'REOPENFLAG ',
# 'RESPGROUP ', 'RESPONSE ', 'SOURCE ', 'geo.ward ', 'ali.answerdate ',
# 'ali.asqdate ', 'ali.companyid ', 'ali.direction ', 'ali.equipment']

# %%
pd_temp.head()
# Out:
#    eventnumber            entrydate              ACKDATE   \
# 0    1802809654  01/28/2018 16.34.50  01/28/2018 16.54.22
# 1    1802809655  01/28/2018 16.34.52                  NaN
# 2    1802809656  01/28/2018 16.34.52                  NaN
# 3    1802809657  01/28/2018 16.34.53                  NaN
# 4    1802809658  01/28/2018 16.35.04  01/28/2018 16.35.56
#
#   ADDROFOCCOVERRIDEFLAG  ADVISEDFLAG   ALINUMBER  ARPFLAG    ATOM   ATOMPOL   \
# 0                      N            N    99221009        N   124.0     124.0
# 1                      N            N    99221014        N  1131.0    1131.0
# 2                      N            Y    99221023        N   314.0     314.0
# 3                      N            N           0        N   611.0     611.0
# 4                      N            N    99221018        N  2222.0    2222.0
#
#   CALLERLOCSTREETDIR       ...      REOPENFLAG  RESPGROUP  RESPONSE  SOURCE   \
# ...

# %%
pdf = pd.DataFrame()

# %%
path = './911call/other/'
files= os.listdir(path)
files
# Out:
# ['chifoia_ehh_01012018_aa.csv',
#  'chifoia_ehh_01012018_ab.csv',
#  'chifoia_ehh_01012018_ac.csv',
#  'chifoia_ehh_01012018_ad.csv',
#  'chifoia_ehh_02012018_aa.csv',
#  'chifoia_ehh_02012018_ab.csv',
#  'chifoia_ehh_02012018_ac.csv',
#  'chifoia_ehh_02012018_ad.csv',
#  'chifoia_ehh_03012018_aa.csv',
#  'chifoia_ehh_03012018_ab.csv',
#  'chifoia_ehh_03012018_ac.csv',
#  'chifoia_ehh_03012018_ad.csv',
#  'chifoia_ehh_04012018_aa.csv',
#  'chifoia_ehh_04012018_ab.csv',
#  'chifoia_ehh_04012018_ac.csv',
#  'chifoia_ehh_04012018_ad.csv',
#  'chifoia_ehh_09012017_aa.csv',
#  'chifoia_ehh_09012017_ab.csv',
#  'chifoia_ehh_09012017_ac.csv',
#  'chifoia_ehh_09012017_ad.csv',
#  'chifoia_ehh_10012017_aa.csv',
#  'chifoia_ehh_10012017_ab.csv',
#  'chifoia_ehh_10012017_ac.csv',
#  'chifoia_ehh_10012017_ad.csv',
#  'chifoia_ehh_11012017_aa.csv',
#  'chifoia_ehh_11012017_ab.csv',
#  'chifoia_ehh_11012017_ac.csv',
#  'chifoia_ehh_11012017_ad.csv',
#  'chifoia_ehh_12012017_aa.csv',
# ...

# %%
for file in files:
    pd_temp = pd.read_csv(path+file,skiprows=1,header=None)
    pd_temp.columns = ['eventnumber', 'entrydate', 'ACKDATE', 'ADDROFOCCOVERRIDEFLAG',
       'ADVISEDFLAG', 'ALINUMBER', 'ARPFLAG', 'ATOM', 'ATOMPOL',
       'CALLERLOCSTREETDIR', 'CALLERLOCSTREETNAME', 'CANCELEDFLAG',
       'CASE_NUMBER_FLAG', 'CATCHUPFLAG', 'CLOSEDATE', 'CLOSEDATEHN',
       'CLRDATE', 'CONDISPGROUP', 'CONTACT', 'DISPATCHED_FLAG',
       'DISPDATE', 'findisposition', 'DISPWKS', 'DUPLICATE_FLAG',
       'ENRDATE', 'ENTRYDATEHN', 'ENTRYWKS', 'FILE_ADVISED_FLAG',
       'FINPRIORITY', 'FINRESPLEVEL', 'FINTYPE', 'INITDISPOSITION',
       'INITPRIORITY', 'INITRESPLEVEL', 'INITTYPE', 'LOCCITY',
       'LOCDISPGROUP', 'LOCOVERRIDEFLAG', 'LOCTYPEFLAG', 'OOSFLAG',
       'OTHERNOTIFIEDFLAG', 'RECDDATE', 'RECDDATEHN', 'REOPENFLAG',
       'RESPGROUP', 'RESPONSE', 'SOURCE', 'geo.ward', 'ali.answerdate',
       'ali.asqdate', 'ali.companyid', 'ali.direction', 'ali.equipment']
    print(pd_temp.shape)
    pdf = pd.concat([pdf,pd_temp])
    print(pdf.shape)
# Out:
# D:\ProgramData\Anaconda3\envs\FinalProject\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (150000, 53)
# (150000, 53)
# (150000, 53)
# (300000, 53)
# (150000, 53)
# (450000, 53)
# (53993, 53)
# (503993, 53)
# (150000, 53)
# (653993, 53)
# (150000, 53)
# (803993, 53)
# (150000, 53)
# (953993, 53)
# (3399, 53)
# (957392, 53)
# (150000, 53)
# (1107392, 53)
# (150000, 53)
# (1257392, 53)
# (150000, 53)
# (1407392, 53)
# (72514, 53)
# (1479906, 53)
# (150000, 53)
# (1629906, 53)
# (150000, 53)
# (1779906, 53)
# (150000, 53)
# (1929906, 53)
# (58941, 53)
# (1988847, 53)
# (150000, 53)
# (2138847, 53)
# (150000, 53)
# (2288847, 53)
# (150000, 53)
# (2438847, 53)
# (76823, 53)
# (2515670, 53)
# (150000, 53)
# (2665670, 53)
# (150000, 53)
# (2815670, 53)
# (150000, 53)
# (2965670, 53)
# (73755, 53)
# (3039425, 53)
# ...

# %%
pdf.head()
# Out:
#    eventnumber            entrydate              ACKDATE  \
# 0   1800100001  01/01/2018 00.00.00                  NaN
# 1   1800100002  01/01/2018 00.00.03                  NaN
# 2   1800100003  01/01/2018 00.00.15  01/01/2018 00.02.15
# 3   1800100004  01/01/2018 00.00.16                  NaN
# 4   1800100005  01/01/2018 00.00.21  01/01/2018 00.03.33
#
#   ADDROFOCCOVERRIDEFLAG ADVISEDFLAG  ALINUMBER ARPFLAG    ATOM  ATOMPOL  \
# 0                     N           N   98907843       N   832.0    832.0
# 1                     N           N          0       N  1224.0   1224.0
# 2                     N           N   98907835       N  1723.0   1723.0
# 3                     Y           N          0     NaN     NaN      NaN
# 4                     N           N   98907838       N   634.0    634.0
#
#   CALLERLOCSTREETDIR      ...      REOPENFLAG RESPGROUP RESPONSE SOURCE  \
# 0                  S      ...               N     832.0      2.0      E
# ...

# %%
pdf.entrydate = pd.to_datetime(pdf.entrydate, format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf.ACKDATE = pd.to_datetime(pdf.ACKDATE, format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf.CLOSEDATE = pd.to_datetime(pdf.CLOSEDATE, format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf.CLRDATE = pd.to_datetime(pdf.CLRDATE, format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf.DISPDATE = pd.to_datetime(pdf.DISPDATE, format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf.ENRDATE = pd.to_datetime(pdf.ENRDATE, format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf.RECDDATE = pd.to_datetime(pdf.RECDDATE, format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf['ali.answerdate'] = pd.to_datetime(pdf['ali.answerdate'], format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf['ali.asqdate'] = pd.to_datetime(pdf['ali.asqdate'], format='%m/%d/%Y %H.%M.%S',errors='coerce')

# %%
pdf.to_csv('./911call/chifoia_history_header_other.csv')

# %%
pdf.head()
# Out:
#    eventnumber           entrydate             ACKDATE ADDROFOCCOVERRIDEFLAG  \
# 0   1800100001 2018-01-01 00:00:00                 NaT                     N
# 1   1800100002 2018-01-01 00:00:03                 NaT                     N
# 2   1800100003 2018-01-01 00:00:15 2018-01-01 00:02:15                     N
# 3   1800100004 2018-01-01 00:00:16                 NaT                     Y
# 4   1800100005 2018-01-01 00:00:21 2018-01-01 00:03:33                     N
#
#   ADVISEDFLAG  ALINUMBER ARPFLAG    ATOM  ATOMPOL CALLERLOCSTREETDIR  \
# 0           N   98907843       N   832.0    832.0                  S
# 1           N          0       N  1224.0   1224.0                NaN
# 2           N   98907835       N  1723.0   1723.0                  W
# 3           N          0     NaN     NaN      NaN                NaN
# 4           N   98907838       N   634.0    634.0                  E
#
#        ...      REOPENFLAG RESPGROUP RESPONSE SOURCE geo.ward  \
# ...
